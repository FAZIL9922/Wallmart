# %% [markdown]
# <a href="https://colab.research.google.com/github/FAZIL9922/Wallmart/blob/main/Walmart_Data_Analysis_And_Visualization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Walmart

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Walmart Inc. is an American multinational retail corporation that operates a chain of hypermarkets, discount department stores, and grocery stores from the United States, headquartered in Bentonville, Arkansas.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Task is to analyze  the sales of  walmart with the data given. (eg: anaglysing weekly sales, which store or department sells most etc.)

# %% [markdown]
# ## DATA ANALYSIS AND VIUALIZATION

# %% [markdown]
# #### Importing all the required libraries and packages.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# %% [markdown]
# #### Reading all the csv files as dataframes using pd.read_csv method.

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
features_df=pd.read_csv('features.csv')
stores_df = pd.read_csv('stores.csv')

# %% [markdown]
# #### Aanalyzing Each imported data frames.

# %% [markdown]
# #### Viewing the data in train_df

# %% [markdown]
# ###### We can see that the dataframe has weekly  sales data in accordance with store department and date.

# %%
required_data_range = train_df.iloc[49999:50010]  # Retrieves rows 50000 to 50009 (inclusive)
required_data_range
# Out:
#        Store  Dept        Date  Weekly_Sales  IsHoliday
# 49999      6     9  2011-05-13      38614.46      False
# 50000      6     9  2011-05-20      40185.02      False
# 50001      6     9  2011-05-27      55265.50      False
# 50002      6     9  2011-06-03      66583.33      False
# 50003      6     9  2011-06-10      57356.09      False
# 50004      6     9  2011-06-17      53333.54      False
# 50005      6     9  2011-06-24      55502.23      False
# 50006      6     9  2011-07-01      60438.80      False
# 50007      6     9  2011-07-08      71246.02      False
# 50008      6     9  2011-07-15      41379.19      False
# 50009      6     9  2011-07-22      46194.61      False

# %%
required_data_condition = train_df[train_df['Store'] > 5]
required_data_condition
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 48789       6     1  2010-02-05      25619.00      False
# 48790       6     1  2010-02-12      43749.81       True
# 48791       6     1  2010-02-19      34750.82      False
# 48792       6     1  2010-02-26      19896.08      False
# 48793       6     1  2010-03-05      22839.36      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [372781 rows x 5 columns]

# %%
train_df.head(50000)
# Out:
#        Store  Dept        Date  Weekly_Sales  IsHoliday
# 0          1     1  2010-02-05      24924.50      False
# 1          1     1  2010-02-12      46039.49       True
# 2          1     1  2010-02-19      41595.55      False
# 3          1     1  2010-02-26      19403.54      False
# 4          1     1  2010-03-05      21827.90      False
# ...      ...   ...         ...           ...        ...
# 49995      6     9  2011-04-15      40107.24      False
# 49996      6     9  2011-04-22      52128.99      False
# 49997      6     9  2011-04-29      44236.57      False
# 49998      6     9  2011-05-06      38702.19      False
# 49999      6     9  2011-05-13      38614.46      False
#
# [50000 rows x 5 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %% [markdown]
# ###### Describe the data in train_df, that is mean count etc of the numerical columns in the data frame.

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train_df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday
# 0      1     1 2010-02-05      24924.50      False
# 1      1     1 2010-02-12      46039.49       True
# 2      1     1 2010-02-19      41595.55      False
# 3      1     1 2010-02-26      19403.54      False
# 4      1     1 2010-03-05      21827.90      False

# %% [markdown]
# ###### This shows how many null values each column in the data frame has, we can see that there are no null values in any columns of the data frame.

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %% [markdown]
# ###### Viewing the test_df

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'IsHoliday'], dtype='object')

# %% [markdown]
# ###### Describing the data in the test dataframe.

# %%
test_df.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %% [markdown]
# ##### Analysing null values in each column.

# %%
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %% [markdown]
# ##### Viewing the features dataframe.

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %% [markdown]
# ##### Viewing the Info of each column in the features dataframe.

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
features_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %% [markdown]
# ##### Finding out about the null values in each column.

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %% [markdown]
# ##### Viewing the stores data frame.

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
stores_df.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %% [markdown]
# ##### Finding the null values in each column.

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %% [markdown]
# ##### Create a new data frame by merging (inner) features data frame to stores data frame  on Store for analysis purpose.

# %%
dataset_m = features_df.merge(stores_df, how= 'inner', on = 'Store')
dataset_m.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.242170         8.106       True    A
# 2        NaN        NaN        NaN  211.289143         8.106      False    A
# 3        NaN        NaN        NaN  211.319643         8.106      False    A
# 4        NaN        NaN        NaN  211.350143         8.106      False    A
#
#      Size
# 0  151315
# 1  151315
# 2  151315
# 3  151315
# 4  151315

# %% [markdown]
# ##### Gathering info regarding the columns of the new data frame.

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### Convering date to date time object.

# %%
from datetime import datetime
#converting date to date time object
dataset_m['Date'] = pd.to_datetime(dataset_m['Date'])
train_df['Date'] = pd.to_datetime(train_df['Date'])
test_df['Date'] = pd.to_datetime(test_df['Date'])
#Extract week and year from the date and make them into new columns.
dataset_m['week'] = dataset_m.Date.dt.isocalendar().week
dataset_m['year'] = dataset_m.Date.dt.isocalendar().year

# %%
dataset_m.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-12        38.51       2.548        NaN        NaN        NaN
# 2      1 2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3      1 2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4      1 2010-03-05        46.50       2.625        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type    Size  \
# 0        NaN        NaN  211.096358         8.106      False    A  151315
# 1        NaN        NaN  211.242170         8.106       True    A  151315
# 2        NaN        NaN  211.289143         8.106      False    A  151315
# 3        NaN        NaN  211.319643         8.106      False    A  151315
# 4        NaN        NaN  211.350143         8.106      False    A  151315
#
#    week  year
# 0     5  2010
# 1     6  2010
# 2     7  2010
# 3     8  2010
# 4     9  2010

# %% [markdown]
# ##### Creating a new df by merging (inner) the train_df and the new data frame dataset_m on  store, date and IsHoliday columns and sorting the values by Store, department and date.

# %%
train_df_1 = train_df.merge(dataset_m, how='inner', on=['Store', 'Date', 'IsHoliday']).sort_values(by=['Store','Dept','Date']).reset_index(drop=True)

# %%
train_df_1.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     1 2010-02-12      46039.49       True        38.51       2.548
# 2      1     1 2010-02-19      41595.55      False        39.93       2.514
# 3      1     1 2010-02-26      19403.54      False        46.63       2.561
# 4      1     1 2010-03-05      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size  week  year
# 0         8.106    A  151315     5  2010
# 1         8.106    A  151315     6  2010
# 2         8.106    A  151315     7  2010
# 3         8.106    A  151315     8  2010
# 4         8.106    A  151315     9  2010

# %%
train_df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # VISUALIZATIONS

# %% [markdown]
# # -------------------------

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Defining a function scatter to plot the scatter plot with the data of the column specified as the function parameter in x axis and weekly sales as the y values.

# %% [markdown]
# ### 1) scatter plot

# %%
def scatter(train_df_1, column):
    #plot the figure
    plt.figure()
    #plot the scatter plot with data from the specified column in x axis and weekly sales in y axis
    plt.scatter(train_df_1[column], train_df_1['Weekly_Sales'])
    #give y label as weekly_sales
    plt.ylabel('Weekly_Sales')
    #Give the xlabel as the column specified as parameter in the function
    plt.xlabel(column)
    plt.grid(True)

# %%
#plot a scatter plot using the scatter function a scatter plot of weekly sales with respect to Store
scatter(train_df_1, 'Store')
#plot a scatter plot using the scatter function a scatter plot of weekly sales with respect to Department
scatter(train_df_1, 'Dept')
plt.show()

# %% [markdown]
# We can see scatter plots of weekly sales with respect to stores and department, we can see that departments between 60 and 80 are performing better.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 2) 3 line plots for weekly sales for eact year

# %% [markdown]
# This is the line plot for weekly sales in the year 2010

# %%
# Assuming train_df_1 is a DataFrame with the necessary columns including 'Week', 'Weekly_Sales', and 'year'

# Convert 'Weekly_Sales' column to numeric
train_df_1['Weekly_Sales'] = pd.to_numeric(train_df_1['Weekly_Sales'], errors='coerce')

# Filtering out mean weekly sales for the year 2010
weekly_sales_2010 = train_df_1[train_df_1['year'] == 2010].groupby('week')['Weekly_Sales'].mean().dropna()

# Plot a line plot with week on the x-axis and sales for that particular week of the filtered year on the y-axis
plt.figure(figsize=(20, 10))
plt.plot(weekly_sales_2010.index, weekly_sales_2010.values, color='red')
plt.grid()

# Plot labels and title
plt.xticks(np.arange(1, 53, step = 1))
plt.xlabel('Week', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.title('Mean Weekly Sales for the Year 2010', fontsize=16)


plt.show()
# weekly_sales_2010 = train_df_1[train_df_1['year'] == 2010].groupby('week')['Weekly_Sales'].mean().dropna()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# This is the line plot for weekly sales in the year 2011

# %%
# Assuming train_df_1 is a DataFrame with the necessary columns including 'Week', 'Weekly_Sales', and 'year'

# Convert 'Weekly_Sales' column to numeric
train_df_1['Weekly_Sales'] = pd.to_numeric(train_df_1['Weekly_Sales'], errors='coerce')

# Filtering out mean weekly sales for the year 2011
weekly_sales_2011 = train_df_1[train_df_1['year'] == 2011].groupby('week')['Weekly_Sales'].mean().dropna()

# Plot a line plot with week on the x-axis and sales for that particular week of the filtered year on the y-axis
plt.figure(figsize=(20, 10))
plt.plot(weekly_sales_2011.index, weekly_sales_2011.values, color='red')
plt.grid()

# Plot labels and title
plt.xticks(np.arange(1, 53, step=1))
plt.xlabel('Week', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.title('Mean Weekly Sales for the Year 2011', fontsize=16)

plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# This is the line plot for weekly sales in the year 2012

# %%
# Assuming train_df_1 is a DataFrame with the necessary columns including 'Week', 'Weekly_Sales', and 'year'

# Convert 'Weekly_Sales' column to numeric
train_df_1['Weekly_Sales'] = pd.to_numeric(train_df_1['Weekly_Sales'], errors='coerce')

# Filtering out mean weekly sales for the year 2012
weekly_sales_2012 = train_df_1[train_df_1['year'] == 2012].groupby('week')['Weekly_Sales'].mean().dropna()

# Plot a line plot with week on the x-axis and sales for that particular week of the filtered year on the y-axis
plt.figure(figsize=(20, 10))
plt.plot(weekly_sales_2012.index, weekly_sales_2012.values, color='red')
plt.grid()

# Plot labels and title

plt.xticks(np.arange(1, 54, step=1))
plt.xlabel('Week', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.title('Mean Weekly Sales for the Year 2012', fontsize=16)

plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 3) Combined line plots for each year (2010,2011,2012)

# %% [markdown]
# #### Plotting the weekly sales for years 2010,2011,2012 on a single plot to compare the sales values with respect to week on each of these specified year for comparing the weekly sales in each year.

# %%
# Assuming weekly_sales_2010, weekly_sales_2011, and weekly_sales_2012 are pandas Series or DataFrames

# Convert to numeric and drop NaN values
weekly_sales_2010 = pd.to_numeric(weekly_sales_2010, errors='coerce').dropna()
weekly_sales_2011 = pd.to_numeric(weekly_sales_2011, errors='coerce').dropna()
weekly_sales_2012 = pd.to_numeric(weekly_sales_2012, errors='coerce').dropna()

plt.figure(figsize=(20, 10))

# Plotting three line plots for weekly sales for each year
plt.plot(weekly_sales_2010.index, weekly_sales_2010.values, label='2010')
plt.plot(weekly_sales_2011.index, weekly_sales_2011.values, label='2011')
plt.plot(weekly_sales_2012.index, weekly_sales_2012.values, label='2012')

plt.grid()

# Plot labels and legends
plt.xticks(np.arange(1, 54, step=1))
plt.title('Average Weekly Sales Per Year', fontsize=20)
plt.xlabel('Week', fontsize=16)
plt.ylabel('Sales', fontsize=16)
plt.legend(loc='best', fontsize=16)
plt.show()

# %% [markdown]
# #### We can see from the combined line lot that on week 51 of 2010 we have the maximum sale

# %% [markdown]
# Line plots between week and weekly sales is a good way to compare sales for each year.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 4) Histogram / Normal Distribution

# %%
f, ax = plt.subplots(figsize=(8, 6))
#Creating a distribution for weekly sales in the dataframe train_df
sns.distplot(train_df['Weekly_Sales'],color='g')
# Out:
# <ipython-input-56-670fb8473c69>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['Weekly_Sales'],color='g')
# <Axes: xlabel='Weekly_Sales', ylabel='Density'>

# %%
#Skewness is a measure of symmetry, or more precisely, the lack of symmetry. A distribution, or data set, is symmetric if it looks the same to the left and right of the center point.
print("Skewness: ", train_df['Weekly_Sales'].skew()) #skewness
#Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution. That is, data sets with high kurtosis tend to have heavy tails, or outliers. Data sets with low kurtosis tend to have light tails, or lack of outliers
print("Kurtosis: ", train_df['Weekly_Sales'].kurt()) #kurtosis
# Out:
# Skewness:  3.2620081854656657
# Kurtosis:  21.49128990832619

# %% [markdown]
# The above code is to determine the skew and kurtosis of the normal distribution.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 5) Box Plot

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
#concatinating the type and column from store_df together to find the relation between stores falling under each type and size.
data = pd.concat([stores_df['Type'], stores_df['Size']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
#Plot a box plot to understand the relation between type and size of stores.
fig = sns.boxplot(x='Type', y='Size', data=data)

# %% [markdown]
# From the above box plots we can see that Type A plots are the largest, ie has the largest size

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 6) Bar Chart On Data Frame

# %%
weekly_sales_store = train_df_1['Weekly_Sales'].groupby(train_df_1['Store']).mean()

# %% [markdown]
# #### Grouping the train_df by store and computing the mean of weekly_sales for each store.

# %% [markdown]
# visualizing the data

# %%
weekly_sales_store
# Out:
# Store
# 1     21710.543621
# 2     26898.070031
# 3      6373.033983
# 4     29161.210415
# 5      5053.415813
# 6     21913.243624
# 7      8358.766148
# 8     13133.014768
# 9      8772.890379
# 10    26332.303819
# 11    19276.762751
# 12    14867.308619
# 13    27355.136891
# 14    28784.851727
# 15     9002.493073
# 16     7863.224124
# 17    12954.393636
# 18    15733.313136
# 19    20362.126734
# 20    29508.301592
# 21    11283.435496
# 22    15181.218886
# 23    19776.180881
# 24    18969.106500
# 25    10308.157810
# 26    14554.129672
# 27    24826.984536
# 28    18714.889803
# 29     8158.810609
# 30     8764.237719
# 31    19681.907464
# 32    16351.621855
# 33     5728.414053
# 34    13522.081671
# 35    13803.596986
# 36     8584.412563
# 37    10297.355026
# 38     7492.478460
# 39    21000.763562
# 40    13763.632803
# 41    17976.004648
# 42    11443.370118
# 43    13415.114118
# 44     6038.929814
# 45    11662.897315
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# #### Converting the data to a pandas dataframe

# %%
weekly_sales_store_df=pd.DataFrame(weekly_sales_store)

# %% [markdown]
# #### Sorting the data frame with respect to weekly sales in Descending order and plotting a var graph on the data frame itself to get a idea about the data.

# %%
weekly_sales_store_df.sort_values("Weekly_Sales",ascending=False).style.bar(align='left',width=98,color='#FFD200')
# Out:
# <style type="text/css">
# #T_34ac0_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 98.0%, transparent 98.0%);
# }
# #T_34ac0_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 96.6%, transparent 96.6%);
# }
# #T_34ac0_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 95.1%, transparent 95.1%);
# }
# #T_34ac0_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 89.4%, transparent 89.4%);
# }
# #T_34ac0_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 87.5%, transparent 87.5%);
# }
# #T_34ac0_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 85.3%, transparent 85.3%);
# }
# #T_34ac0_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 79.2%, transparent 79.2%);
# }
# #T_34ac0_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 67.6%, transparent 67.6%);
# }
# #T_34ac0_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 66.8%, transparent 66.8%);
# }
# #T_34ac0_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 63.9%, transparent 63.9%);
# }
# #T_34ac0_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 61.3%, transparent 61.3%);
# }
# #T_34ac0_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 59.0%, transparent 59.0%);
# }
# #T_34ac0_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 58.6%, transparent 58.6%);
# }
# #T_34ac0_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 57.0%, transparent 57.0%);
# }
# #T_34ac0_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 55.8%, transparent 55.8%);
# }
# #T_34ac0_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 54.7%, transparent 54.7%);
# }
# #T_34ac0_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 51.8%, transparent 51.8%);
# }
# #T_34ac0_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 45.3%, transparent 45.3%);
# }
# #T_34ac0_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 42.8%, transparent 42.8%);
# }
# #T_34ac0_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 40.6%, transparent 40.6%);
# }
# #T_34ac0_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 39.3%, transparent 39.3%);
# }
# #T_34ac0_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 38.1%, transparent 38.1%);
# }
# #T_34ac0_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 35.1%, transparent 35.1%);
# }
# #T_34ac0_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 34.9%, transparent 34.9%);
# }
# #T_34ac0_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 33.9%, transparent 33.9%);
# }
# #T_34ac0_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 33.5%, transparent 33.5%);
# }
# #T_34ac0_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 32.4%, transparent 32.4%);
# }
# #T_34ac0_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 31.7%, transparent 31.7%);
# }
# #T_34ac0_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 26.5%, transparent 26.5%);
# }
# #T_34ac0_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 25.6%, transparent 25.6%);
# }
# #T_34ac0_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 25.0%, transparent 25.0%);
# }
# #T_34ac0_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 21.1%, transparent 21.1%);
# }
# #T_34ac0_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 21.0%, transparent 21.0%);
# }
# #T_34ac0_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 15.8%, transparent 15.8%);
# }
# #T_34ac0_row34_col0, #T_34ac0_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 14.9%, transparent 14.9%);
# }
# #T_34ac0_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 14.2%, transparent 14.2%);
# }
# #T_34ac0_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 13.2%, transparent 13.2%);
# }
# #T_34ac0_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 12.4%, transparent 12.4%);
# }
# #T_34ac0_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 11.3%, transparent 11.3%);
# }
# #T_34ac0_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 9.8%, transparent 9.8%);
# }
# #T_34ac0_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 5.3%, transparent 5.3%);
# }
# #T_34ac0_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 3.9%, transparent 3.9%);
# }
# #T_34ac0_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFD200 2.7%, transparent 2.7%);
# }
# #T_34ac0_row44_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_34ac0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ac0_level0_col0" class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ac0_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_34ac0_row0_col0" class="data row0 col0" >29508.301592</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_34ac0_row1_col0" class="data row1 col0" >29161.210415</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_34ac0_row2_col0" class="data row2 col0" >28784.851727</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_34ac0_row3_col0" class="data row3 col0" >27355.136891</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_34ac0_row4_col0" class="data row4 col0" >26898.070031</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_34ac0_row5_col0" class="data row5 col0" >26332.303819</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_34ac0_row6_col0" class="data row6 col0" >24826.984536</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_34ac0_row7_col0" class="data row7 col0" >21913.243624</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_34ac0_row8_col0" class="data row8 col0" >21710.543621</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row9" class="row_heading level0 row9" >39</th>
#       <td id="T_34ac0_row9_col0" class="data row9 col0" >21000.763562</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_34ac0_row10_col0" class="data row10 col0" >20362.126734</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row11" class="row_heading level0 row11" >23</th>
#       <td id="T_34ac0_row11_col0" class="data row11 col0" >19776.180881</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row12" class="row_heading level0 row12" >31</th>
#       <td id="T_34ac0_row12_col0" class="data row12 col0" >19681.907464</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_34ac0_row13_col0" class="data row13 col0" >19276.762751</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row14" class="row_heading level0 row14" >24</th>
#       <td id="T_34ac0_row14_col0" class="data row14 col0" >18969.106500</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row15" class="row_heading level0 row15" >28</th>
#       <td id="T_34ac0_row15_col0" class="data row15 col0" >18714.889803</td>
#     </tr>
#     <tr>
#       <th id="T_34ac0_level0_row16" class="row_heading level0 row16" >41</t

# %% [markdown]
# ### We can see that Store number 20 has the highest weekly sales (20508.301592)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Sorting the data frame with respect to weekly sales in Ascending order and plotting a var graph on the data frame itself to get a idea about the data.

# %%
weekly_sales_store_df.sort_values("Weekly_Sales").style.bar(align='left',width=98,color='#ff00bf')
# Out:
# <style type="text/css">
# #T_af6f4_row0_col0 {
#   width: 10em;
# }
# #T_af6f4_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 2.7%, transparent 2.7%);
# }
# #T_af6f4_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 3.9%, transparent 3.9%);
# }
# #T_af6f4_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 5.3%, transparent 5.3%);
# }
# #T_af6f4_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 9.8%, transparent 9.8%);
# }
# #T_af6f4_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 11.3%, transparent 11.3%);
# }
# #T_af6f4_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 12.4%, transparent 12.4%);
# }
# #T_af6f4_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 13.2%, transparent 13.2%);
# }
# #T_af6f4_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 14.2%, transparent 14.2%);
# }
# #T_af6f4_row9_col0, #T_af6f4_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 14.9%, transparent 14.9%);
# }
# #T_af6f4_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 15.8%, transparent 15.8%);
# }
# #T_af6f4_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 21.0%, transparent 21.0%);
# }
# #T_af6f4_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 21.1%, transparent 21.1%);
# }
# #T_af6f4_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 25.0%, transparent 25.0%);
# }
# #T_af6f4_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 25.6%, transparent 25.6%);
# }
# #T_af6f4_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 26.5%, transparent 26.5%);
# }
# #T_af6f4_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 31.7%, transparent 31.7%);
# }
# #T_af6f4_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 32.4%, transparent 32.4%);
# }
# #T_af6f4_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 33.5%, transparent 33.5%);
# }
# #T_af6f4_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 33.9%, transparent 33.9%);
# }
# #T_af6f4_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 34.9%, transparent 34.9%);
# }
# #T_af6f4_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 35.1%, transparent 35.1%);
# }
# #T_af6f4_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 38.1%, transparent 38.1%);
# }
# #T_af6f4_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 39.3%, transparent 39.3%);
# }
# #T_af6f4_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 40.6%, transparent 40.6%);
# }
# #T_af6f4_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 42.8%, transparent 42.8%);
# }
# #T_af6f4_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 45.3%, transparent 45.3%);
# }
# #T_af6f4_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 51.8%, transparent 51.8%);
# }
# #T_af6f4_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 54.7%, transparent 54.7%);
# }
# #T_af6f4_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 55.8%, transparent 55.8%);
# }
# #T_af6f4_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 57.0%, transparent 57.0%);
# }
# #T_af6f4_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 58.6%, transparent 58.6%);
# }
# #T_af6f4_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 59.0%, transparent 59.0%);
# }
# #T_af6f4_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 61.3%, transparent 61.3%);
# }
# #T_af6f4_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 63.9%, transparent 63.9%);
# }
# #T_af6f4_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 66.8%, transparent 66.8%);
# }
# #T_af6f4_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 67.6%, transparent 67.6%);
# }
# #T_af6f4_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 79.2%, transparent 79.2%);
# }
# #T_af6f4_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 85.3%, transparent 85.3%);
# }
# #T_af6f4_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 87.5%, transparent 87.5%);
# }
# #T_af6f4_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 89.4%, transparent 89.4%);
# }
# #T_af6f4_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 95.1%, transparent 95.1%);
# }
# #T_af6f4_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 96.6%, transparent 96.6%);
# }
# #T_af6f4_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff00bf 98.0%, transparent 98.0%);
# }
# </style>
# <table id="T_af6f4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af6f4_level0_col0" class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af6f4_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_af6f4_row0_col0" class="data row0 col0" >5053.415813</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row1" class="row_heading level0 row1" >33</th>
#       <td id="T_af6f4_row1_col0" class="data row1 col0" >5728.414053</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row2" class="row_heading level0 row2" >44</th>
#       <td id="T_af6f4_row2_col0" class="data row2 col0" >6038.929814</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af6f4_row3_col0" class="data row3 col0" >6373.033983</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row4" class="row_heading level0 row4" >38</th>
#       <td id="T_af6f4_row4_col0" class="data row4 col0" >7492.478460</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_af6f4_row5_col0" class="data row5 col0" >7863.224124</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row6" class="row_heading level0 row6" >29</th>
#       <td id="T_af6f4_row6_col0" class="data row6 col0" >8158.810609</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_af6f4_row7_col0" class="data row7 col0" >8358.766148</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row8" class="row_heading level0 row8" >36</th>
#       <td id="T_af6f4_row8_col0" class="data row8 col0" >8584.412563</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row9" class="row_heading level0 row9" >30</th>
#       <td id="T_af6f4_row9_col0" class="data row9 col0" >8764.237719</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_af6f4_row10_col0" class="data row10 col0" >8772.890379</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row11" class="row_heading level0 row11" >15</th>
#       <td id="T_af6f4_row11_col0" class="data row11 col0" >9002.493073</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row12" class="row_heading level0 row12" >37</th>
#       <td id="T_af6f4_row12_col0" class="data row12 col0" >10297.355026</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row13" class="row_heading level0 row13" >25</th>
#       <td id="T_af6f4_row13_col0" class="data row13 col0" >10308.157810</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row14" class="row_heading level0 row14" >21</th>
#       <td id="T_af6f4_row14_col0" class="data row14 col0" >11283.435496</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row15" class="row_heading level0 row15" >42</th>
#       <td id="T_af6f4_row15_col0" class="data row15 col0" >11443.370118</td>
#     </tr>
#     <tr>
#       <th id="T_af6f4_level0_row16" class="row_heading level0 row16" >45</th>
#       <td

# %% [markdown]
# ### We can see that Store number 5 has the least weekly sales (5053.415813)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 7) Bar graph for mean weekly sales for each store.

# %% [markdown]
# ## Plotting a bar graph with store number as x values and mean weekly sales for that store as the y values.

# %%
import matplotlib.pyplot as plt

# Assuming weekly_sales_store is a pandas Series or DataFrame with store numbers as index and mean weekly sales as values

# Plotting the figure.
plt.figure(figsize=(25, 12))

# Creating a barplot with stores in x-axis and mean weekly sales for each store as y-values.
plt.bar(weekly_sales_store.index, weekly_sales_store.values, color='green')

# Plot a grid
plt.grid()

# Give title, x and y labels for the plot
plt.xticks(np.arange(1,53,step=1))
plt.title('Average Weekly Sales Per Store', fontsize=20)
plt.xlabel('Store Number', fontsize=16)
plt.ylabel('Sales Per Store', fontsize=16)

plt.show()

# %% [markdown]
# 1)We can see that this plot is a great way to analyse how each store is performing sales wise.
#
# 2)From the plot we can see that store number 20 has the highesst mean weekly sales, followed by store 4 and then store 14.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Grouping the train_df by Department and computing the mean of weekly_sales for each Department.

# %% [markdown]
# ### 8) Bar chart on Data Frame.

# %%
weekly_sales_Dept = train_df['Weekly_Sales'].groupby(train_df['Dept']).mean()

# %% [markdown]
# converting it to a pandas dataframe

# %%
weekly_sales_Dept_df= pd.DataFrame(weekly_sales_Dept)

# %%
weekly_sales_Dept_df
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515
# ...            ...
# 95    69824.423080
# 96    15210.942761
# 97    14255.576919
# 98     6824.694889
# 99      415.487065
#
# [81 rows x 1 columns]

# %% [markdown]
# #### Sorting the data frame with respect to weekly sales in Descending order and plotting a var graph on the data frame itself to get a idea about the data.

# %%
weekly_sales_Dept_df.sort_values("Weekly_Sales",ascending=False).style.bar(align='left',width=98,color='#d65f5f')
# Out:
# <style type="text/css">
# #T_76e6e_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.0%, transparent 98.0%);
# }
# #T_76e6e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.0%, transparent 91.0%);
# }
# #T_76e6e_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.6%, transparent 79.6%);
# }
# #T_76e6e_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.9%, transparent 65.9%);
# }
# #T_76e6e_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.2%, transparent 59.2%);
# }
# #T_76e6e_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_76e6e_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.5%, transparent 58.5%);
# }
# #T_76e6e_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.8%, transparent 56.8%);
# }
# #T_76e6e_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.9%, transparent 43.9%);
# }
# #T_76e6e_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.5%, transparent 43.5%);
# }
# #T_76e6e_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.0%, transparent 40.0%);
# }
# #T_76e6e_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.3%, transparent 39.3%);
# }
# #T_76e6e_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.2%, transparent 35.2%);
# }
# #T_76e6e_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.9%, transparent 33.9%);
# }
# #T_76e6e_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.5%, transparent 31.5%);
# }
# #T_76e6e_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.2%, transparent 31.2%);
# }
# #T_76e6e_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.6%, transparent 28.6%);
# }
# #T_76e6e_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.8%, transparent 27.8%);
# }
# #T_76e6e_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.3%, transparent 26.3%);
# }
# #T_76e6e_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.0%, transparent 26.0%);
# }
# #T_76e6e_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.0%, transparent 25.0%);
# }
# #T_76e6e_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.9%, transparent 23.9%);
# }
# #T_76e6e_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.4%, transparent 20.4%);
# }
# #T_76e6e_row23_col0, #T_76e6e_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_76e6e_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.8%, transparent 19.8%);
# }
# #T_76e6e_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.4%, transparent 19.4%);
# }
# #T_76e6e_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.9%, transparent 18.9%);
# }
# #T_76e6e_row28_col0, #T_76e6e_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.6%, transparent 18.6%);
# }
# #T_76e6e_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.0%, transparent 18.0%);
# }
# #T_76e6e_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.5%, transparent 17.5%);
# }
# #T_76e6e_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.9%, transparent 15.9%);
# }
# #T_76e6e_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.4%, transparent 15.4%);
# }
# #T_76e6e_row34_col0, #T_76e6e_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
# }
# #T_76e6e_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.3%, transparent 13.3%);
# }
# #T_76e6e_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.7%, transparent 11.7%);
# }
# #T_76e6e_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.6%, transparent 10.6%);
# }
# #T_76e6e_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.0%, transparent 10.0%);
# }
# #T_76e6e_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.7%, transparent 9.7%);
# }
# #T_76e6e_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.6%, transparent 9.6%);
# }
# #T_76e6e_row42_col0, #T_76e6e_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.9%, transparent 8.9%);
# }
# #T_76e6e_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.4%, transparent 8.4%);
# }
# #T_76e6e_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.3%, transparent 8.3%);
# }
# #T_76e6e_row46_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.5%, transparent 7.5%);
# }
# #T_76e6e_row47_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.4%, transparent 7.4%);
# }
# #T_76e6e_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.2%, transparent 7.2%);
# }
# #T_76e6e_row49_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.8%, transparent 6.8%);
# }
# #T_76e6e_row50_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.5%, transparent 6.5%);
# }
# #T_76e6e_row51_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.2%, transparent 6.2%);
# }
# #T_76e6e_row52_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.1%, transparent 6.1%);
# }
# #T_76e6e_row53_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.5%, transparent 5.5%);
# }
# #T_76e6e_row54_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.4%, transparent 5.4%);
# }
# #T_76e6e_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_76e6e_row56_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.8%, transparent 4.8%);
# }
# #T_76e6e_row57_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.4%, transparent 4.4%);
# }
# #T_76e6e_row58_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.1%, transparent 4.1%);
# }
# #T_76e6e_row59_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.8%, transparent 3.8%);
# }
# #T_76e6e_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.5%, transparent 3.5%);
# }
# #T_76e6e_row61_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_76e6e_row62_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.0%, transparent 3.0%);
# }
# #T_76e6e_row63_col0, #T_76e6e_row64_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.6%, transparent 2.6%);
# }
# #T_76e6e_row65_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.5%, transparent 2.5%);
# }
# #T_76e6e_row66_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.2%, transparent 2.2%);
# }
# #T_76e6e_row67_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_76e6e_row68_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.8%, transparent 1.8%);
# }
# #T_76e6e_row69_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_76e6e_row70_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_76e6e_row71_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_76e6e_row72_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_76e6e_row73_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# #T_76e6e_row74_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_76e6e_row75_col0, #T_76e6e_row76_col0, #T_76e6e_row77_col0, #T_76e6e_row78_col0, #T_76e6e_row79_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, trans

# %% [markdown]
# ### We can see that Department number 92 has the largest weekly sales.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ####  Sorting the data frame with respect to weekly sales in Ascending order and plotting a var graph on the data frame itself to get a idea about the data.

# %%
weekly_sales_Dept_df.sort_values('Weekly_Sales').style.bar(align='left',width=98,color='#bfff00')
# Out:
# <style type="text/css">
# #T_87689_row0_col0 {
#   width: 10em;
# }
# #T_87689_row1_col0, #T_87689_row2_col0, #T_87689_row3_col0, #T_87689_row4_col0, #T_87689_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.0%, transparent 0.0%);
# }
# #T_87689_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.2%, transparent 0.2%);
# }
# #T_87689_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.4%, transparent 0.4%);
# }
# #T_87689_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.5%, transparent 0.5%);
# }
# #T_87689_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.6%, transparent 0.6%);
# }
# #T_87689_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.8%, transparent 0.8%);
# }
# #T_87689_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 0.9%, transparent 0.9%);
# }
# #T_87689_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 1.8%, transparent 1.8%);
# }
# #T_87689_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 2.1%, transparent 2.1%);
# }
# #T_87689_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 2.2%, transparent 2.2%);
# }
# #T_87689_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 2.5%, transparent 2.5%);
# }
# #T_87689_row16_col0, #T_87689_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 2.6%, transparent 2.6%);
# }
# #T_87689_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 3.0%, transparent 3.0%);
# }
# #T_87689_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 3.1%, transparent 3.1%);
# }
# #T_87689_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 3.5%, transparent 3.5%);
# }
# #T_87689_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 3.8%, transparent 3.8%);
# }
# #T_87689_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 4.1%, transparent 4.1%);
# }
# #T_87689_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 4.4%, transparent 4.4%);
# }
# #T_87689_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 4.8%, transparent 4.8%);
# }
# #T_87689_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 5.0%, transparent 5.0%);
# }
# #T_87689_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 5.4%, transparent 5.4%);
# }
# #T_87689_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 5.5%, transparent 5.5%);
# }
# #T_87689_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 6.1%, transparent 6.1%);
# }
# #T_87689_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 6.2%, transparent 6.2%);
# }
# #T_87689_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 6.5%, transparent 6.5%);
# }
# #T_87689_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 6.8%, transparent 6.8%);
# }
# #T_87689_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 7.2%, transparent 7.2%);
# }
# #T_87689_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 7.4%, transparent 7.4%);
# }
# #T_87689_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 7.5%, transparent 7.5%);
# }
# #T_87689_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 8.3%, transparent 8.3%);
# }
# #T_87689_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 8.4%, transparent 8.4%);
# }
# #T_87689_row37_col0, #T_87689_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 8.9%, transparent 8.9%);
# }
# #T_87689_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 9.6%, transparent 9.6%);
# }
# #T_87689_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 9.7%, transparent 9.7%);
# }
# #T_87689_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 10.0%, transparent 10.0%);
# }
# #T_87689_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 10.6%, transparent 10.6%);
# }
# #T_87689_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 11.7%, transparent 11.7%);
# }
# #T_87689_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 13.3%, transparent 13.3%);
# }
# #T_87689_row45_col0, #T_87689_row46_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 14.0%, transparent 14.0%);
# }
# #T_87689_row47_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 15.4%, transparent 15.4%);
# }
# #T_87689_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 15.9%, transparent 15.9%);
# }
# #T_87689_row49_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 17.5%, transparent 17.5%);
# }
# #T_87689_row50_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 18.0%, transparent 18.0%);
# }
# #T_87689_row51_col0, #T_87689_row52_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 18.6%, transparent 18.6%);
# }
# #T_87689_row53_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 18.9%, transparent 18.9%);
# }
# #T_87689_row54_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 19.4%, transparent 19.4%);
# }
# #T_87689_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 19.8%, transparent 19.8%);
# }
# #T_87689_row56_col0, #T_87689_row57_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 20.2%, transparent 20.2%);
# }
# #T_87689_row58_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 20.4%, transparent 20.4%);
# }
# #T_87689_row59_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 23.9%, transparent 23.9%);
# }
# #T_87689_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 25.0%, transparent 25.0%);
# }
# #T_87689_row61_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 26.0%, transparent 26.0%);
# }
# #T_87689_row62_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 26.3%, transparent 26.3%);
# }
# #T_87689_row63_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 27.8%, transparent 27.8%);
# }
# #T_87689_row64_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 28.6%, transparent 28.6%);
# }
# #T_87689_row65_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 31.2%, transparent 31.2%);
# }
# #T_87689_row66_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 31.5%, transparent 31.5%);
# }
# #T_87689_row67_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 33.9%, transparent 33.9%);
# }
# #T_87689_row68_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 35.2%, transparent 35.2%);
# }
# #T_87689_row69_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 39.3%, transparent 39.3%);
# }
# #T_87689_row70_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 40.0%, transparent 40.0%);
# }
# #T_87689_row71_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 43.5%, transparent 43.5%);
# }
# #T_87689_row72_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 43.9%, transparent 43.9%);
# }
# #T_87689_row73_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 56.8%, transparent 56.8%);
# }
# #T_87689_row74_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 58.5%, transparent 58.5%);
# }
# #T_87689_row75_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 58.9%, transparent 58.9%);
# }
# #T_87689_row76_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 59.2%, transparent 59.2%);
# }
# #T_87689_row77_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 65.9%, transparent 65.9%);
# }
# #T_87689_row78_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 79.6%, transparent 79.6%);
# }
# #T_87689_row79_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #bfff00 91.0%, transparent 91.0%);
# }
# #T_87689_row80_col0 {
#   width: 10em;
#   background: linea

# %% [markdown]
# ### We can see that department 47 has a cumulative negative value for weekly sales followed by department 43 which has a very low weekly sale of 1.193333

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 9)Bar graph for mean weekly sales for each Department.

# %% [markdown]
# ## Plotting a bar graph with Department number as x values and mean weekly sales for that store as the y values.

# %%
import matplotlib.pyplot as plt

# Assuming weekly_sales_Dept is a pandas Series or DataFrame with department names or numbers as index and mean weekly sales as values

# Plotting the figure.
plt.figure(figsize=(35, 12))

# Creating a barplot with department in x-axis and mean weekly sales for each department as y-values.
plt.bar(weekly_sales_Dept.index, weekly_sales_Dept.values)

# Plot a grid
plt.grid()

# Give title, x and y labels for the plot
plt.xticks(np.arange(1,100,step = 1))
plt.title('Average Weekly Sales Per Department', fontsize=20)
plt.xlabel('Department', fontsize=16)
plt.ylabel('Sales', fontsize=16)

plt.show()

# %% [markdown]
# We can see that weekly sales is highest for department 92.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 10) Series of line plots for mean sales with respect to Departments.

# %% [markdown]
# #### Creating line plots of mean weekly sales for each department in the dataframe.

# %%
#Creating a data frame grouped by grouping the train_df on department and date.
grouped=train_df_1.groupby(['Dept','Date']).mean().reset_index()

#Filtering out Department, Date, Weekly sales from the new data frame grouped.
data=grouped[['Dept','Date','Weekly_Sales']]

#Finding out unique values in the department column.
dept=train_df_1['Dept'].unique()
#Sort the unique values in the column
dept.sort()
#Divide the departments into 4 batches
dept_1=dept[0:20]
dept_2=dept[20:40]
dept_3=dept[40:60]
dept_4=dept[60:]

#Create subplots with 2 rows and 2 columns and adjusting the spacing between the subplots.
fig, ax = plt.subplots(2,2,figsize=(20,10))
fig.subplots_adjust(wspace=0.5, hspace=0.5)
fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9)


#For each batch containg departments and for each department in each batch plot the weekly sales in accordance with date.
for i in dept_1 :
    data_1=data[data['Dept']==i]
    ax[0,0].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')

for i in dept_2 :
    data_1=data[data['Dept']==i]
    ax[0,1].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')

for i in dept_3 :
    data_1=data[data['Dept']==i]
    ax[1,0].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')

for i in dept_4 :
    data_1=data[data['Dept']==i]
    ax[1,1].plot(data_1['Date'], data_1['Weekly_Sales'],label='Dept_1_mean_sales')


#Give each subplot a suitable title
ax[0,0].set_title('Mean sales record by department (0-19)')
ax[0,1].set_title('Mean sales record by department (20-39)')
ax[1,0].set_title('Mean sales record by department (40-59)')
ax[1,1].set_title('Mean sales record by department (60-)')

#Give each Subplot y and x labels
ax[0,0].set_ylabel('Mean sales With Respect To Specified Departments')
ax[0,0].set_xlabel('Date')
ax[0,1].set_ylabel('Mean sales With Respect To Specified Departments')
ax[0,1].set_xlabel('Date')
ax[1,0].set_ylabel('Mean sales With Respect To Specified Departments')
ax[1,0].set_xlabel('Date')
ax[1,1].set_ylabel('Mean sales With Respect To Specified Departments')
ax[1,1].set_xlabel('Date')


plt.show()
# Out:
# <ipython-input-48-076c7dfe7231>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped=train_df_1.groupby(['Dept','Date']).mean().reset_index()

# %% [markdown]
# 1)The sales level is different by department
#
#
# 2)There is some peaked points around January and May, thus indicating high sales during those times.
#
# We can see that departments and date are good features to predict the sales.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 11) Histogram / Normal Distribution
#
# *   List item
# *   List item

# %% [markdown]
# ### Plotting the normal distribution where sales is greater than zero.

# %%
#Data for sales over zero
train_over_zero_sales=train_df[train_df['Weekly_Sales']>0]
#Data for sales less than zero
train_below_zero_sales=train_df[train_df['Weekly_Sales']<=0]
#Natural log of data for sales over zero
sales_over_zero_sales = np.log1p(train_over_zero_sales['Weekly_Sales'])
#plotting a histogram and normal distribution for data with sales over zero.
f, ax = plt.subplots(figsize=(8, 6))
sns.distplot(sales_over_zero_sales)
# Out:
# <ipython-input-63-4e2c3bf546c6>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sales_over_zero_sales)
# <Axes: xlabel='Weekly_Sales', ylabel='Density'>

# %%
print("Skewness: ", sales_over_zero_sales.skew()) #skewness
print("Kurtosis: ", sales_over_zero_sales.kurt()) #kurtosis
# Out:
# Skewness:  -1.2011878481918052
# Kurtosis:  1.5541238937236335

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 12) Heatmap

# %% [markdown]
# ### Plotting a heatmap to determine the correlation between columns in the data frame.

# %%
sns.set(style = 'white')


fig, ax = plt.subplots(figsize= (25, 15))
sns.heatmap(train_df_1.corr(), cmap = 'icefire', vmax = 0.3, center = 0, square = True, linewidth= 0.5, cbar_kws = {'shrink': 0.5}, annot = True)
# Out:
# <ipython-input-51-551b98a4362b>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_df_1.corr(), cmap = 'icefire', vmax = 0.3, center = 0, square = True, linewidth= 0.5, cbar_kws = {'shrink': 0.5}, annot = True)
# <Axes: >

# %% [markdown]
# We can see that there are various column that have very week correlation and thus its always better to drop these columns before modelling since that columns dosent contribute much to the process.
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# Also,some columns are strongly correlated . One of them must be dropped else they would carry similar information to the model.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------
